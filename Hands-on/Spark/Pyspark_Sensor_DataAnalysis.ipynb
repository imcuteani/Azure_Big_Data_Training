# %%
from pyspark.sql import*
from pyspark.sql.types import*
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>0</td><td>application_1666868187339_0004</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://hn1-cg-spa.a1z1ekxghp3ezlfrondafhs2xa.rx.internal.cloudapp.net:8088/proxy/application_1666868187339_0004/">Link</a></td><td><a target="_blank" href="http://wn1-cg-spa.a1z1ekxghp3ezlfrondafhs2xa.rx.internal.cloudapp.net:30060/node/containerlogs/container_1666868187339_0004_01_000001/livy">Link</a></td><td>✔</td></tr></table>
# SparkSession available as 'spark'.
# /usr/bin/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
# Create a Dataframe and table from sample Blob data
csvFile = spark.read.csv('/HdiSamples/HdiSamples/SensorSampleData/hvac/HVAC.csv',header = True, inferSchema=True)
csvFile.write.saveAsTable("hvacnew")

# %%
# %%sql
# SELECT BuildingID, (TargetTemp - ActualTemp) AS temp_diff, Date from hvacnew where Date = \"6/1/13\"
